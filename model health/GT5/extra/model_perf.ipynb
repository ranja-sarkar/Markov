# %%
import pandas as pd
import matplotlib.pyplot as plt

#from pandas.plotting import register_matplotlib_converters
#register_matplotlib_converters()

# %%
# Loading test output from the model and converting to time index

##filename = r'Brunei_Champion_GT5_tst_pred_01Dec2018_01Jul2019.csv'
##dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
##df = pd.read_csv(filename, parse_dates = ['timestamp'], date_parser = dateparse)
##df.set_index('timestamp', inplace = True)
##df['date'] = df.index

# %%
filename1 = 'results_w1d_m3hr_nu0.05_gam0.005.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df1 = pd.read_csv(filename1, parse_dates = ['timestamp'])
df1.set_index('timestamp', inplace = True)


filename2 = 'results_w1d_m3hr_nu0.1_gam0.0025.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df2 = pd.read_csv(filename2, parse_dates = ['timestamp'])
df2.set_index('timestamp',inplace = True)


filename3 = 'results_w1d_m3hr_nu0.1_gam0.005.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df3 = pd.read_csv(filename3, parse_dates = ['timestamp'])
df3.set_index('timestamp', inplace = True)

filename4 = 'results_w1d_m3hr_nu0.1_gam0.0075.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df4 = pd.read_csv(filename4, parse_dates = ['timestamp'])
df4.set_index('timestamp', inplace = True)

filename5 = 'results_w1d_m3hr_nu0.2_gam0.005.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df5 = pd.read_csv(filename5, parse_dates = ['timestamp'])
df5.set_index('timestamp', inplace = True)

# %%
import matplotlib.style as style
style.available
style.use('seaborn-deep')

ax = df1['anomaly_ratio'].plot(style = '-', figsize = (10,5), grid = True, linewidth = 2)
ax = df2['anomaly_ratio'].plot(style = '-', figsize = (10,5), grid = True, linewidth = 2)
ax = df3['anomaly_ratio'].plot(style = '-', figsize = (10,5), grid = True, linewidth = 2)
ax = df4['anomaly_ratio'].plot(style = '-', figsize = (10,5), grid = True, linewidth = 2)
ax = df5['anomaly_ratio'].plot(style = '-', figsize = (10,5), grid = True, linewidth = 2)
ax.set_ylabel('Anomaly Ratio', color = '#000000')
#ax.set_title('')
plt.show()

# %%
#%matplotlib notebook

fig, ax = plt.subplots()
fig.autofmt_xdate(bottom = 0.2, rotation = 30)
fig.suptitle('GT4_w1d_m3hr', fontsize = 10)

ax.set_xlabel('Weeks', color = 'blue')
ax.set_ylabel('Anomaly Ratio', color = 'blue')
plt.plot(df1.index, df1['anomaly_ratio'], linestyle = '-', label = "nu0.05_gamma0.005", color = 'blue')
plt.plot(df2.index, df2['anomaly_ratio'], linestyle = '-', label = "nu0.1_gamma0.0025", color = 'yellow')
plt.plot(df3.index, df3['anomaly_ratio'], linestyle = '-', label = "nu0.1_gamma0.005 (Baseline)", color = 'green')
#plt.plot(df4.index, df4['anomaly_ratio'], linestyle = '-', label = "nu0.1_gamma0.0075")
plt.plot(df5.index, df5['anomaly_ratio'], linestyle = '-', label = "nu0.2_gamma0.005", color = 'red')
ax.axhline(0.2, color = 'black', linewidth = 1.5, linestyle = '--', label = 'Threshold')
ax.grid()
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
fig.autofmt_xdate(bottom = 0.2, rotation = 30)
fig.suptitle('GT4_w1d_m3hr', fontsize = 10)

ax.set_xlabel('Weeks', color = 'blue')
ax.set_ylabel('Flips Ratio', color = 'blue')
plt.plot(df1.index, df1['flips_ratio'], linestyle = '-', label = "nu0.05_gamma0.005", color = 'blue')
plt.plot(df2.index, df2['flips_ratio'], linestyle = '-', label = "nu0.1_gamma0.0025", color = 'yellow')
plt.plot(df3.index, df3['flips_ratio'], linestyle = '-', label = "nu0.1_gamma0.005 (Baseline)", color = 'green')
#plt.plot(df4.index, df4['flips_ratio'], linestyle = '-', color = 'orange', label = "nu0.1_gamma0.0075")
#plt.plot(df4.index, df4['flips_ratio'], linestyle = '-', label = "nu0.1_gamma0.0075")
plt.plot(df5.index, df5['flips_ratio'], linestyle = '-', label = "nu0.2_gamma0.005", color = 'red')
ax.axhline(0.015, color = 'black', linewidth = 1.5, linestyle = '--', label = 'Threshold')

ax.grid()
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots(figsize = (9, 6))
fig.autofmt_xdate(bottom = 0.2, rotation = 30)
fig.suptitle('GT4_w1d_m3hr', fontsize = 12)

ax.set_xlabel('Weeks', color = 'blue')
ax.set_ylabel('Model Uptime Ratio', color = 'blue')
plt.plot(df1.index, df1['model_uptime_ratio'], linestyle = '-', label = "nu0.05_gamma0.005", color = 'blue')
plt.plot(df2.index, df2['model_uptime_ratio'], linestyle = '-', label = "nu0.1_gamma0.0025", color = 'yellow')
plt.plot(df3.index, df3['model_uptime_ratio'], linestyle = '-', label = "nu0.1_gamma0.005 (Baseline)", color = 'green')
#plt.plot(df4.index, df4['model_uptime_ratio'], linestyle = '-', label = "nu0.1_gamma0.0075")
plt.plot(df5.index, df5['model_uptime_ratio'], linestyle = '-', label = "nu0.2_gamma0.005", color = 'red')
ax.axhline(0.8, color = 'black', linewidth = 1.5, linestyle = '--', label = 'Threshold')
ax.grid()
plt.legend(loc = 'lower left')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
#%matplotlib inline

# %%
#df1.fillna(0)
filename1 = 'results_w1d_m3hr_nu0.05_gam0.005.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df1 = pd.read_csv(filename1, parse_dates = ['timestamp'])
df1.set_index('timestamp', inplace = True)


filename2 = 'results_w1d_m3hr_nu0.1_gam0.0025.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df2 = pd.read_csv(filename2, parse_dates = ['timestamp'])
df2.set_index('timestamp',inplace = True)


filename3 = 'results_w1d_m3hr_nu0.1_gam0.005.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df3 = pd.read_csv(filename3, parse_dates = ['timestamp'])
df3.set_index('timestamp', inplace = True)

filename4 = 'results_w1d_m3hr_nu0.1_gam0.0075.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df4 = pd.read_csv(filename4, parse_dates = ['timestamp'])
df4.set_index('timestamp', inplace = True)

filename5 = 'results_w1d_m3hr_nu0.2_gam0.005.csv'
#dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df5 = pd.read_csv(filename5, parse_dates = ['timestamp'])
df5.set_index('timestamp', inplace = True)

# %%
a1 = df1['anomaly_ratio'].tolist()
a2 = df2['anomaly_ratio'].tolist()
a3 = df3['anomaly_ratio'].tolist()
#a4 = df4['anomaly_ratio'].tolist()
a5 = df5['anomaly_ratio'].tolist()

# %%
anomaly_data = [a1, a2, a3, a5]

# %%
# Create a figure instance
fig = plt.figure(1, figsize = (9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(anomaly_data, patch_artist = True)

## Custom x-axis labels
ax.set_xticklabels(['nu0.05_gam0.005', 'nu0.1_gam0.0025', 'nu0.1_gam0.005 (Baseline)', 'nu0.2_gam0.005'])
ax.set_ylabel('Anomaly Ratio', color = 'blue')
ax.set_title('GT4_w1d_m3hr')

colors = ['blue', 'yellow', 'green', 'red']
for box in bp['boxes']:
#    # change outline color
#    box.set(color = '#000000', linewidth = 2)
#    # change fill color
#    box.set(facecolor = '#ffffff' )
    for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)
    
    
    
## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color = '#000000', linewidth = 2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color = '#000000', linewidth = 2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color = '#000000', linewidth = 2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker = 'o', color = '#e7298a', alpha = 0.5)

# Save the figure
#fig.savefig('fig1.png', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
f1 = df1['flips_ratio'].tolist()
f2 = df2['flips_ratio'].tolist()
f3 = df3['flips_ratio'].tolist()
#f4 = df4['flips_ratio'].tolist()
f5 = df5['flips_ratio'].tolist()

# %%
flips_data = [f1, f2, f3, f5]

# %%
# Create a figure instance
fig = plt.figure(1, figsize = (9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(flips_data, patch_artist = True)

## Custom x-axis labels
ax.set_xticklabels(['nu0.05_gam0.005', 'nu0.1_gam0.0025', 'nu0.1_gam0.005 (Baseline)', 'nu0.2_gam0.005'])
ax.set_ylabel('Flips Ratio', color = 'blue')
ax.set_title('GT4_w1d_m3hr')

## change outline color, fill color and linewidth of the boxes
colors =  ['blue', 'yellow', 'green', 'red']
for box in bp['boxes']:
    # change outline color
#    box.set( color = '#000000', linewidth = 2)
    # change fill color
    #box.set( facecolor = '#ffffff' )
#    box.set( facecolor = '#6a8f61' )
    for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)
    

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color = '#000000', linewidth = 2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color = '#000000', linewidth = 2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color = '#000000', linewidth = 2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker = 'o', color = '#e7298a', alpha = 0.5)

# Save the figure
#fig.savefig('fig1.png', bbox_inches='tight')

# %%
m1 = df1['model_uptime_ratio'].tolist()
m2 = df2['model_uptime_ratio'].tolist()
m3 = df3['model_uptime_ratio'].tolist()
#m4 = df4['model_uptime_ratio'].tolist()
m5 = df5['model_uptime_ratio'].tolist()

# %%
model_uptime_data = [m1, m2, m3, m5]

# %%
# Create a figure instance
fig = plt.figure(1, figsize = (9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(model_uptime_data, patch_artist = True)

## Custom x-axis labels
ax.set_xticklabels(['nu0.05_gam0.005', 'nu0.1_gam0.0025', 'nu0.1_gam0.005 (Baseline)', 'nu0.2_gam0.005'])
ax.set_ylabel('Model Uptime Ratio', color = 'blue')
ax.set_title('GTD_w1d_m3hr')

colors = ['blue', 'yellow', 'green', 'red']
## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
#    box.set(color = '#000000', linewidth = 2)
    # change fill color
    #box.set( facecolor = '#ffffff' )
#    box.set(facecolor = '#517a85' )
    for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)
    

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color = '#000000', linewidth = 2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color = '#000000', linewidth = 2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color = '#000000', linewidth = 2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker = 'o', color = '#e7298a', alpha = 0.5)

# Save the figure
#fig.savefig('fig1.png', bbox_inches='tight')

# %%
import matplotlib.style as style
style.available
style.use('seaborn-deep')
ax = uptime_ratio_df.plot(style='-', figsize=(10,5), grid=True, linewidth=2)
ax.set_ylabel('Uptime Ratio', color='#000000')
ax.set_title('Uptime Ratio')
plt.show()
